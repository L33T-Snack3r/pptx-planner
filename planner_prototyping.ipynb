# %% [markdown]
# ## Planner prototyping
# Notebook for prototyping the powerpoint planner

# %%
import sys
sys.path.append("../") # go to parent dir
from llm.llmwrapper import LLM
from loguru import logger

# %%
llm = LLM(provider="gemini", model="gemini-1.5-pro")
# Out:
# INFO:root:LLM initialized
# INFO:root:Provider: gemini
# INFO:root:Model: gemini-1.5-pro

# %% [markdown]
# ### Step 1: brainstorm

# %%
query = "Make a presentation about building a system which takes an internal company database of contract documents, and based on a user query, helps find the most relevant contract document"

# %%
brainstorm_prompt = \
f"""
You are a tech consultant, and you have been given the following request:

"{query}"

Before starting work on the request, you need to brainstorm.
From a technical perspective, how could something like this be done? 
Please use the following pointers to guide your thought process:
- What is the most cutting-edge way to do this?
- How can this be done using cloud services?
"""
print(brainstorm_prompt)
# Out:
# You are a tech consultant, and you have been given the following request:
#
# "Make a presentation about building a system which takes an internal company database of contract documents, and based on a user query, helps find the most relevant contract document"
#
# Before starting work on the request, you need to brainstorm.
# From a technical perspective, how could something like this be done?
# Please use the following pointers to guide your thought process:
# - What is the most cutting-edge way to do this?
# - How can this be done using cloud services?

# %%
response = llm.call(query=brainstorm_prompt)
print(response['text'])
# Out:
# INFO:google_genai.models:AFC is enabled with max remote calls: 10.
# INFO:httpx:HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-1.5-pro:generateContent "HTTP/1.1 200 OK"
# INFO:google_genai.models:AFC remote call 1 is done.
# ## Brainstorming: Contract Document Search System
#
# **Goal:** Build a system that takes an internal company database of contract documents and, based on a user query, helps find the most relevant contract document.
#
# **Cutting-Edge Approach:**
#
# The most cutting-edge approach would leverage **vector embeddings** and **large language models (LLMs)**. This allows for semantic search, going beyond keyword matching to understand the meaning and context of both the query and the contract documents.
#
# 1. **Document Preprocessing:**
#     * **Optical Character Recognition (OCR):** If contracts are scanned images, use OCR to extract text.
#     * **Cleaning and Normalization:** Remove noise, standardize formatting, and handle special characters.
#     * **Chunking:** Divide large contracts into smaller, manageable chunks (paragraphs or sections) to improve context and performance.
#
# 2. **Embedding Generation:**
#     * **Sentence Transformers:** Use pre-trained sentence transformers (e.g., all-mpnet-base-v2) to generate vector embeddings for each chunk. These embeddings capture the semantic meaning of the text.
#
# 3. **Vector Database:**
#     * **Pinecone, Weaviate, Faiss (self-hosted):** Store the embeddings in a vector database optimized for similarity search.  These databases allow for efficient retrieval of the most similar chunks based on the query embedding.
#
# 4. **Query Processing:**
#     * **Embedding Generation:** Generate an embedding for the user's query using the same sentence transformer.
#     * **Similarity Search:** Query the vector database with the query embedding to find the most similar chunks.
#
# 5. **Relevance Ranking and Retrieval:**
#     * **Hybrid Approach:** Combine vector similarity scores with other relevance signals like keyword matching, document metadata (e.g., contract type, date), and potentially even LLM-based relevance scoring.
#     * **Re-ranking with LLMs:** Use an LLM to re-rank the top retrieved chunks based on the query, considering context and nuanced relationships.
#
# 6. **Presentation of Results:**
#     * **Snippet Generation:**  Use the LLM to generate informative snippets from the most relevant chunks, highlighting the parts that answer the query.
#     * **Contextualized Document View:** Display the relevant contract document with highlighted sections corresponding to the query.
#     * **Question Answering:** Allow users to ask follow-up questions about the retrieved contracts, leveraging the LLM's understanding of the content.
#
#
# **Cloud Services Implementation:**
#
# This system can be effectively implemented using various cloud services:
#
# * **Document Storage:** AWS S3, Azure Blob Storage, Google Cloud Storage for storing the original contract documents.
# * **Compute:** AWS Lambda, Azure Functions, Google Cloud Functions for serverless functions to handle preprocessing, embedding generation, and query processing.
# * **Vector Database:** Managed services like Pinecone or Weaviate, or self-hosting Faiss on a cloud VM.
# * **LLM Integration:** API access to LLMs like OpenAI, Cohere, or AI21.
# * **Search Service (Optional):** Integrate with a cloud-based search service like Elasticsearch or Solr for keyword-based search and filtering.
# * **Workflow Orchestration:** AWS Step Functions, Azure Logic Apps, or Google Cloud Workflows to manage the different stages of the pipeline.
# * **API Gateway:** Expose the functionality through an API for integration with other applications.
# * **Frontend:** Develop a user-friendly web interface using cloud-hosted frontend frameworks like React, Angular, or Vue.js.
#
#
# **Advantages of this approach:**
#
# * **Semantic Search:** Captures the meaning behind the query and documents, leading to more accurate results.
# * **Scalability:** Cloud services allow for easy scaling to handle large datasets and high query volumes.
# * **Maintainability:** Serverless functions and managed services reduce operational overhead.
# * **Extensibility:** The system can be easily extended with new features like question answering and summarization.
#
#
# **Challenges:**
#
# * **Cost:** LLMs and vector databases can be expensive, especially for large datasets.
# * **Complexity:** Implementing and managing the different components can be complex.
# * **Data Privacy and Security:**  Ensure compliance with relevant regulations when handling sensitive contract data.
#
#
# This brainstorming provides a solid foundation for building a powerful and efficient contract document search system.  Further investigation and refinement will be needed during the design and implementation phases.

# %% [markdown]
# ### Step 2: Plan structure of presentation

# %%
brainstorm_response = response['text']

# %%
skeleton_prompt = \
f"""
You are a tech consultant, and you have been given the following request:

"{query}"

After consulting with a senior software engineer, he has provided you the following approach to build such a system:
"{brainstorm_response}"

It is now time for you to create the proposal slides.
Before deciding on what content should go on the slides, 
create a well-thought out plan of the structure that this presentation should follow.

Some of the sections you should include are:
- The background of the problem
- Your proposed solution and why it will work / benefits of the solution
- The infrastructure and tech stack
- The required human resources
- The timeline
- The cost involved in this project

Depending on the situation, be creative and add in any other sections that you think might add value.
If this proposal is successful, you will get a big raise!
"""
print(skeleton_prompt)
# Out:
# You are a tech consultant, and you have been given the following request:
#
# "Make a presentation about building a system which takes an internal company database of contract documents, and based on a user query, helps find the most relevant contract document"
#
# After consulting with a senior software engineer, he has provided you the following approach to build such a system:
# "## Brainstorming: Contract Document Search System
#
# **Goal:** Build a system that takes an internal company database of contract documents and, based on a user query, helps find the most relevant contract document.
#
# **Cutting-Edge Approach:**
#
# The most cutting-edge approach would leverage **vector embeddings** and **large language models (LLMs)**. This allows for semantic search, going beyond keyword matching to understand the meaning and context of both the query and the contract documents.
#
# 1. **Document Preprocessing:**
#     * **Optical Character Recognition (OCR):** If contracts are scanned images, use OCR to extract text.
#     * **Cleaning and Normalization:** Remove noise, standardize formatting, and handle special characters.
#     * **Chunking:** Divide large contracts into smaller, manageable chunks (paragraphs or sections) to improve context and performance.
#
# 2. **Embedding Generation:**
#     * **Sentence Transformers:** Use pre-trained sentence transformers (e.g., all-mpnet-base-v2) to generate vector embeddings for each chunk. These embeddings capture the semantic meaning of the text.
#
# 3. **Vector Database:**
#     * **Pinecone, Weaviate, Faiss (self-hosted):** Store the embeddings in a vector database optimized for similarity search.  These databases allow for efficient retrieval of the most similar chunks based on the query embedding.
#
# 4. **Query Processing:**
#     * **Embedding Generation:** Generate an embedding for the user's query using the same sentence transformer.
#     * **Similarity Search:** Query the vector database with the query embedding to find the most similar chunks.
#
# 5. **Relevance Ranking and Retrieval:**
#     * **Hybrid Approach:** Combine vector similarity scores with other relevance signals like keyword matching, document metadata (e.g., contract type, date), and potentially even LLM-based relevance scoring.
#     * **Re-ranking with LLMs:** Use an LLM to re-rank the top retrieved chunks based on the query, considering context and nuanced relationships.
#
# 6. **Presentation of Results:**
#     * **Snippet Generation:**  Use the LLM to generate informative snippets from the most relevant chunks, highlighting the parts that answer the query.
#     * **Contextualized Document View:** Display the relevant contract document with highlighted sections corresponding to the query.
#     * **Question Answering:** Allow users to ask follow-up questions about the retrieved contracts, leveraging the LLM's understanding of the content.
#
#
# **Cloud Services Implementation:**
#
# This system can be effectively implemented using various cloud services:
#
# * **Document Storage:** AWS S3, Azure Blob Storage, Google Cloud Storage for storing the original contract documents.
# * **Compute:** AWS Lambda, Azure Functions, Google Cloud Functions for serverless functions to handle preprocessing, embedding generation, and query processing.
# * **Vector Database:** Managed services like Pinecone or Weaviate, or self-hosting Faiss on a cloud VM.
# * **LLM Integration:** API access to LLMs like OpenAI, Cohere, or AI21.
# * **Search Service (Optional):** Integrate with a cloud-based search service like Elasticsearch or Solr for keyword-based search and filtering.
# * **Workflow Orchestration:** AWS Step Functions, Azure Logic Apps, or Google Cloud Workflows to manage the different stages of the pipeline.
# * **API Gateway:** Expose the functionality through an API for integration with other applications.
# * **Frontend:** Develop a user-friendly web interface using cloud-hosted frontend frameworks like React, Angular, or Vue.js.
#
#
# **Advantages of this approach:**
#
# * **Semantic Search:** Captures the meaning behind the query and documents, leading to more accurate results.
# * **Scalability:** Cloud services allow for easy scaling to handle large datasets and high query volumes.
# * **Maintainability:** Serverless functions and managed services reduce operational overhead.
# * **Extensibility:** The system can be easily extended with new features like question answering and summarization.
#
#
# **Challenges:**
#
# * **Cost:** LLMs and vector databases can be expensive, especially for large datasets.
# * **Complexity:** Implementing and managing the different components can be complex.
# * **Data Privacy and Security:**  Ensure compliance with relevant regulations when handling sensitive contract data.
#
#
# This brainstorming provides a solid foundation for building a powerful and efficient contract document search system.  Further investigation and refinement will be needed during the design and implementation phases.
# "
#
# It is now time for you to create the proposal slides.
# Before deciding on what content should go on the slides,
# create a well-thought out plan of the structure that this presentation should follow.
#
# Some of the sections you should include are:
# - The background of the problem
# - Your proposed solution and why it will work / benefits of the solution
# - The infrastructure and tech stack
# - The required human resources
# - The timeline
# - The cost involved in this project
#
# Depending on the situation, be creative and add in any other sections that you think might add value.

# %%
skeleton_response = llm.call(query=skeleton_prompt)
print(skeleton_response['text'])
# Out:
# INFO:google_genai.models:AFC is enabled with max remote calls: 10.
# INFO:httpx:HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-1.5-pro:generateContent "HTTP/1.1 200 OK"
# INFO:google_genai.models:AFC remote call 1 is done.
# ## Presentation Structure Plan: Contract Document Search System
#
# This presentation aims to secure approval for building a cutting-edge contract document search system leveraging vector embeddings and LLMs.  It will address the current challenges, propose a robust solution, and outline the resources and timeline required for successful implementation.
#
# **I. Introduction (Slide 1)**
#
# * **Title:** Revolutionizing Contract Search: A Modern Approach
# * **Subtitle:**  Unlocking the Power of Your Contract Data
# * **Brief Overview:**  Introduce the current challenges with contract search and the potential benefits of a modern, AI-powered solution.  Highlight the value proposition: faster access to critical information, improved efficiency, and reduced risk.
#
# **II. The Problem (Slides 2-3)**
#
# * **Current State:** Describe the existing contract management process and its limitations.  Focus on pain points like slow search speeds, keyword reliance, difficulty finding specific clauses, and the time wasted manually reviewing documents.
# * **Business Impact:** Quantify the negative impact of these inefficiencies.  For example, estimate the time spent on contract review, the potential for missed deadlines or overlooked clauses, and the associated financial risks.  Use visuals (charts, graphs) to illustrate the impact.
#
# **III. The Solution (Slides 4-6)**
#
# * **Overview:** Introduce the proposed solution: an AI-powered search system using vector embeddings and LLMs.  Explain the concept of semantic search and its advantages over traditional keyword-based methods.
# * **Key Features and Benefits:**  Highlight the core functionalities: semantic search, relevance ranking, snippet generation, contextualized document view, and question answering.  Emphasize the benefits: improved accuracy, faster search, better insights, and enhanced decision-making.
# * **Illustrative Example:**  Showcase a realistic example of how the system would work in practice.  Use a mock-up search interface to demonstrate the user experience and the quality of the results.
#
# **IV. Technical Architecture (Slides 7-8)**
#
# * **System Diagram:** Present a clear and concise diagram illustrating the system architecture, including data flow, key components (OCR, embedding generation, vector database, LLM), and cloud services.
# * **Technology Stack:**  Detail the chosen technologies for each component, justifying the selections based on performance, scalability, cost-effectiveness, and security.  Mention specific tools and services (e.g., Sentence Transformers, Pinecone, OpenAI).
#
# **V. Implementation Plan (Slides 9-10)**
#
# * **Phased Approach:** Outline a phased implementation plan with clear milestones and deliverables.  Start with a pilot project focusing on a subset of contracts and gradually expand to the full dataset.
# * **Timeline:** Provide a realistic timeline for each phase, including development, testing, deployment, and training.
#
# **VI. Team and Resources (Slide 11)**
#
# * **Required Expertise:** Identify the key roles and skills needed for the project (e.g., software engineers, data scientists, cloud architects, legal experts).
# * **Resource Allocation:**  Specify the estimated human resources required for each phase, including internal staff and external consultants.
#
# **VII. Cost and ROI (Slide 12)**
#
# * **Cost Breakdown:**  Present a detailed cost breakdown, including cloud service fees, software licenses, personnel costs, and other expenses.
# * **Return on Investment (ROI):**  Project the potential ROI of the system by quantifying the time savings, efficiency gains, and risk reduction.  Compare the cost of implementation with the long-term benefits.
#
# **VIII. Data Privacy and Security (Slide 13)**
#
# * **Security Measures:**  Address data privacy and security concerns.  Outline the measures that will be taken to protect sensitive contract data, including access control, encryption, and compliance with relevant regulations.
#
# **IX.  Future Enhancements (Slide 14)**
#
# * **Expansion and Integration:**  Discuss potential future enhancements, such as integration with other internal systems (e.g., CRM, legal management software) and expansion to other document types.
#
# **X. Conclusion and Call to Action (Slide 15)**
#
# * **Recap of Benefits:**  Reiterate the key benefits of the proposed solution and its alignment with business objectives.
# * **Call to Action:**  Clearly state the next steps and request approval to proceed with the project.
#
#
# **Appendix (Optional)**
#
# * **Detailed Technical Specifications:** Provide more in-depth technical information for those interested.
# * **Glossary of Terms:** Explain key technical terms for a non-technical audience.
#
#
# This structured approach will ensure a clear, concise, and persuasive presentation that effectively communicates the value and feasibility of the proposed contract document search system.

# %% [markdown]
# ### Step 3: Create slide content

# %%
slide_content_prompt = \
f"""
You are a tech consultant, and you have been given the following request:

"{query}"

After consulting with a senior software engineer, he has provided you the following approach to build such a system:
"{brainstorm_response}"

Based on the advice of the senior software engineer, you have planned out your presentation:
"{skeleton_response['text']}"

Following the plan you have created above, and referencing the technical advice of the senior software engineer,
describe the content that will appear on EACH slide in detail.

Pay extra attention to the following points:
1) If a diagram or image should go on a slide (e.g. an infrastructure diagram, organization chart or a GANTT chart etc.), 
you must describe it with enough detail such that someone reading the description would be able to reproduce it perfectly.

2) This slide content plan will be passed on to another person, so the slide descriptions must be as precise and specific as possible.

3) Think carefully about whether or not the needs of the client are being met with this proposal.

If this proposal is successful, you will get a big raise!
"""
print(slide_content_prompt)
# Out:
# You are a tech consultant, and you have been given the following request:
#
# "Make a presentation about building a system which takes an internal company database of contract documents, and based on a user query, helps find the most relevant contract document"
#
# After consulting with a senior software engineer, he has provided you the following approach to build such a system:
# "## Brainstorming: Contract Document Search System
#
# **Goal:** Build a system that takes an internal company database of contract documents and, based on a user query, helps find the most relevant contract document.
#
# **Cutting-Edge Approach:**
#
# The most cutting-edge approach would leverage **vector embeddings** and **large language models (LLMs)**. This allows for semantic search, going beyond keyword matching to understand the meaning and context of both the query and the contract documents.
#
# 1. **Document Preprocessing:**
#     * **Optical Character Recognition (OCR):** If contracts are scanned images, use OCR to extract text.
#     * **Cleaning and Normalization:** Remove noise, standardize formatting, and handle special characters.
#     * **Chunking:** Divide large contracts into smaller, manageable chunks (paragraphs or sections) to improve context and performance.
#
# 2. **Embedding Generation:**
#     * **Sentence Transformers:** Use pre-trained sentence transformers (e.g., all-mpnet-base-v2) to generate vector embeddings for each chunk. These embeddings capture the semantic meaning of the text.
#
# 3. **Vector Database:**
#     * **Pinecone, Weaviate, Faiss (self-hosted):** Store the embeddings in a vector database optimized for similarity search.  These databases allow for efficient retrieval of the most similar chunks based on the query embedding.
#
# 4. **Query Processing:**
#     * **Embedding Generation:** Generate an embedding for the user's query using the same sentence transformer.
#     * **Similarity Search:** Query the vector database with the query embedding to find the most similar chunks.
#
# 5. **Relevance Ranking and Retrieval:**
#     * **Hybrid Approach:** Combine vector similarity scores with other relevance signals like keyword matching, document metadata (e.g., contract type, date), and potentially even LLM-based relevance scoring.
#     * **Re-ranking with LLMs:** Use an LLM to re-rank the top retrieved chunks based on the query, considering context and nuanced relationships.
#
# 6. **Presentation of Results:**
#     * **Snippet Generation:**  Use the LLM to generate informative snippets from the most relevant chunks, highlighting the parts that answer the query.
#     * **Contextualized Document View:** Display the relevant contract document with highlighted sections corresponding to the query.
#     * **Question Answering:** Allow users to ask follow-up questions about the retrieved contracts, leveraging the LLM's understanding of the content.
#
#
# **Cloud Services Implementation:**
#
# This system can be effectively implemented using various cloud services:
#
# * **Document Storage:** AWS S3, Azure Blob Storage, Google Cloud Storage for storing the original contract documents.
# * **Compute:** AWS Lambda, Azure Functions, Google Cloud Functions for serverless functions to handle preprocessing, embedding generation, and query processing.
# * **Vector Database:** Managed services like Pinecone or Weaviate, or self-hosting Faiss on a cloud VM.
# * **LLM Integration:** API access to LLMs like OpenAI, Cohere, or AI21.
# * **Search Service (Optional):** Integrate with a cloud-based search service like Elasticsearch or Solr for keyword-based search and filtering.
# * **Workflow Orchestration:** AWS Step Functions, Azure Logic Apps, or Google Cloud Workflows to manage the different stages of the pipeline.
# * **API Gateway:** Expose the functionality through an API for integration with other applications.
# * **Frontend:** Develop a user-friendly web interface using cloud-hosted frontend frameworks like React, Angular, or Vue.js.
#
#
# **Advantages of this approach:**
#
# * **Semantic Search:** Captures the meaning behind the query and documents, leading to more accurate results.
# * **Scalability:** Cloud services allow for easy scaling to handle large datasets and high query volumes.
# * **Maintainability:** Serverless functions and managed services reduce operational overhead.
# * **Extensibility:** The system can be easily extended with new features like question answering and summarization.
#
#
# **Challenges:**
#
# * **Cost:** LLMs and vector databases can be expensive, especially for large datasets.
# * **Complexity:** Implementing and managing the different components can be complex.
# * **Data Privacy and Security:**  Ensure compliance with relevant regulations when handling sensitive contract data.
#
#
# This brainstorming provides a solid foundation for building a powerful and efficient contract document search system.  Further investigation and refinement will be needed during the design and implementation phases.
# "
#
# Based on the advice of the senior software engineer, you have planned out your presentation:
# "## Presentation Structure Plan: Contract Document Search System
#
# This presentation aims to secure approval for building a cutting-edge contract document search system leveraging vector embeddings and LLMs.  It will address the current challenges, propose a robust solution, and outline the resources and timeline required for successful implementation.
#
# **I. Introduction (Slide 1)**
#
# * **Title:** Revolutionizing Contract Search: A Modern Approach
# * **Subtitle:**  Unlocking the Power of Your Contract Data
# * **Brief Overview:**  Introduce the current challenges with contract search and the potential benefits of a modern, AI-powered solution.  Highlight the value proposition: faster access to critical information, improved efficiency, and reduced risk.
#
# **II. The Problem (Slides 2-3)**
#
# * **Current State:** Describe the existing contract management process and its limitations.  Focus on pain points like slow search speeds, keyword reliance, difficulty finding specific clauses, and the time wasted manually reviewing documents.
# * **Business Impact:** Quantify the negative impact of these inefficiencies.  For example, estimate the time spent on contract review, the potential for missed deadlines or overlooked clauses, and the associated financial risks.  Use visuals (charts, graphs) to illustrate the impact.
#
# **III. The Solution (Slides 4-6)**
#
# * **Overview:** Introduce the proposed solution: an AI-powered search system using vector embeddings and LLMs.  Explain the concept of semantic search and its advantages over traditional keyword-based methods.
# * **Key Features and Benefits:**  Highlight the core functionalities: semantic search, relevance ranking, snippet generation, contextualized document view, and question answering.  Emphasize the benefits: improved accuracy, faster search, better insights, and enhanced decision-making.
# * **Illustrative Example:**  Showcase a realistic example of how the system would work in practice.  Use a mock-up search interface to demonstrate the user experience and the quality of the results.
#
# **IV. Technical Architecture (Slides 7-8)**
#
# * **System Diagram:** Present a clear and concise diagram illustrating the system architecture, including data flow, key components (OCR, embedding generation, vector database, LLM), and cloud services.
# * **Technology Stack:**  Detail the chosen technologies for each component, justifying the selections based on performance, scalability, cost-effectiveness, and security.  Mention specific tools and services (e.g., Sentence Transformers, Pinecone, OpenAI).
#
# **V. Implementation Plan (Slides 9-10)**
#
# * **Phased Approach:** Outline a phased implementation plan with clear milestones and deliverables.  Start with a pilot project focusing on a subset of contracts and gradually expand to the full dataset.
# * **Timeline:** Provide a realistic timeline for each phase, including development, testing, deployment, and training.
#
# **VI. Team and Resources (Slide 11)**
#
# * **Required Expertise:** Identify the key roles and skills needed for the project (e.g., software engineers, data scientists, cloud architects, legal experts).
# * **Resource Allocation:**  Specify the estimated human resources required for each phase, including internal staff and external consultants.
#
# **VII. Cost and ROI (Slide 12)**
#
# * **Cost Breakdown:**  Present a detailed cost breakdown, including cloud service fees, software licenses, personnel costs, and other expenses.
# * **Return on Investment (ROI):**  Project the potential ROI of the system by quantifying the time savings, efficiency gains, and risk reduction.  Compare the cost of implementation with the long-term benefits.
#
# **VIII. Data Privacy and Security (Slide 13)**
#
# * **Security Measures:**  Address data privacy and security concerns.  Outline the measures that will be taken to protect sensitive contract data, including access control, encryption, and compliance with relevant regulations.
#
# **IX.  Future Enhancements (Slide 14)**
#
# * **Expansion and Integration:**  Discuss potential future enhancements, such as integration with other internal systems (e.g., CRM, legal management software) and expansion to other document types.
#
# **X. Conclusion and Call to Action (Slide 15)**
#
# * **Recap of Benefits:**  Reiterate the key benefits of the proposed solution and its alignment with business objectives.
# * **Call to Action:**  Clearly state the next steps and request approval to proceed with the project.
#
#
# **Appendix (Optional)**
#
# * **Detailed Technical Specifications:** Provide more in-depth technical information for those interested.
# * **Glossary of Terms:** Explain key technical terms for a non-technical audience.
#
#
# This structured approach will ensure a clear, concise, and persuasive presentation that effectively communicates the value and feasibility of the proposed contract document search system.
# "
#
# Following the plan you have created above, and referencing the technical advice of the senior software engineer,
# describe the content that will appear on EACH slide in detail.
#
# Pay extra attention to the following points:
# 1) If a diagram or image should go on a slide (e.g. an infrastructure diagram, organization chart or a GANTT chart etc.),
# you must describe it with enough detail such that someone reading the description would be able to reproduce it perfectly.
#
# 2) This slide content plan will be passed on to another person, so the slide descriptions must be as precise and specific as possible.
#
# 3) Think carefully about whether or not the needs of the client are being met with this proposal.
#
# If this proposal is successful, you will get a big raise!

# %%
slide_content_response = llm.call(query=slide_content_prompt)['text']
print(slide_content_response)
# Out:
# INFO:google_genai.models:AFC is enabled with max remote calls: 10.
# INFO:httpx:HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-1.5-pro:generateContent "HTTP/1.1 200 OK"
# INFO:google_genai.models:AFC remote call 1 is done.
# ## Slide Content Details: Contract Document Search System
#
# **I. Introduction (Slide 1)**
#
# * **Title:** Revolutionizing Contract Search: A Modern Approach (Large, bold font, positioned at the top)
# * **Subtitle:** Unlocking the Power of Your Contract Data (Smaller font, below the title)
# * **Visual:** A stylized image representing contract data (e.g., a magnifying glass over a contract document, or a network of interconnected documents).
# * **Brief Overview Text:** "Currently, locating specific information within our contract database is a time-consuming and inefficient process.  This impacts our ability to quickly respond to business needs and increases the risk of overlooking critical clauses.  This presentation introduces a cutting-edge, AI-powered solution that will transform how we access and utilize our contract data, enabling faster access to critical information, improved efficiency, and reduced risk."
#
#
# **II. The Problem (Slide 2)**
#
# * **Title:** Current Challenges in Contract Management
# * **Bullet Points:**
#     * Slow and cumbersome search process.
#     * Reliance on keyword matching, leading to inaccurate or incomplete results.
#     * Difficulty finding specific clauses or provisions.
#     * Time wasted manually reviewing numerous documents.
#     * Version control issues and difficulty tracking changes.
#     * Lack of centralized access and sharing capabilities.
# * **Visual:** A simple graphic depicting a frustrated person searching through a large pile of documents.
#
#
# **III. The Problem (Slide 3)**
#
# * **Title:** Business Impact of Inefficient Contract Management
# * **Chart:** A bar graph illustrating the quantified impact of the current inefficiencies.
#     * **X-axis:** Categories like "Time spent on contract review," "Potential cost of missed deadlines," "Risk associated with overlooked clauses."
#     * **Y-axis:** Quantified values (e.g., hours per week, dollars, percentage of contracts with errors).  Use realistic data based on company estimates or industry benchmarks.
# * **Text:** Briefly explain the data presented in the chart, emphasizing the financial and operational costs of the current system.
#
#
# **IV. The Solution (Slide 4)**
#
# * **Title:** Introducing an AI-Powered Contract Search System
# * **Text:** "Our proposed solution leverages the power of artificial intelligence to revolutionize contract search.  Using vector embeddings and Large Language Models (LLMs), the system understands the meaning and context of both your queries and the contract documents, enabling semantic search that goes beyond simple keyword matching."
# * **Visual:** A conceptual diagram showing a user's query being processed by the AI system and returning relevant contract documents.
#
#
# **V. The Solution (Slide 5)**
#
# * **Title:** Key Features and Benefits
# * **Table:**  Two columns: "Feature" and "Benefit."
#     * **Rows:**
#         * Semantic Search:  Finds relevant documents even if they don't contain the exact keywords.
#         * Relevance Ranking:  Prioritizes the most relevant results based on meaning and context.
#         * Snippet Generation:  Provides concise summaries of the relevant sections.
#         * Contextualized Document View: Highlights the parts of the contract that answer the query.
#         * Question Answering: Allows users to ask follow-up questions about the contract content.
# * **Visual:** Icons representing each feature.
#
#
# **VI. The Solution (Slide 6)**
#
# * **Title:** Illustrative Example
# * **Mock-up:** A realistic mock-up of the search interface. Show a sample query (e.g., "What are the termination clauses for this contract?") and the resulting output (e.g., snippets from relevant sections, highlighted text within the contract document).
# * **Text:** Briefly explain the example, highlighting the ease of use and the accuracy of the results.
#
#
# **VII. Technical Architecture (Slide 7)**
#
# * **Title:** System Architecture
# * **Diagram:** A flowchart illustrating the data flow and system components.
#     * **Input:** Contract Documents (various formats)
#     * **OCR (Optical Character Recognition):** Converts scanned images to text.
#     * **Preprocessing:** Cleaning, normalization, and chunking of text.
#     * **Embedding Generation:** Sentence Transformers create vector embeddings.
#     * **Vector Database (Pinecone/Weaviate/Faiss):** Stores and indexes embeddings.
#     * **Query Processing:** User query is embedded and compared to the database.
#     * **LLM (OpenAI/Cohere/AI21):** Re-ranking, snippet generation, question answering.
#     * **Output:** Relevant contract snippets, highlighted documents, answers to questions.
# * **Arrows:** Connect each component to show the flow of data.
#
#
# **VIII. Technical Architecture (Slide 8)**
#
# * **Title:** Technology Stack
# * **Table:** Two columns: "Component" and "Technology."
#     * **Rows:**
#         * Document Storage: AWS S3
#         * Compute: AWS Lambda
#         * Vector Database: Pinecone (example)
#         * LLM Integration: OpenAI API (example)
#         * Search Service (Optional): Elasticsearch
#         * Workflow Orchestration: AWS Step Functions
#         * API Gateway: AWS API Gateway
#         * Frontend: React
#
#
# **IX. Implementation Plan (Slide 9)**
#
# * **Title:** Phased Implementation
# * **Table:** Three columns: "Phase," "Deliverables," and "Timeline."
#     * **Rows:**
#         * Phase 1 (Pilot):  Develop and test the system with a subset of contracts (e.g., 1000 contracts).  2 months.
#         * Phase 2 (Expansion):  Expand the system to the full contract database.  3 months.
#         * Phase 3 (Integration): Integrate with other internal systems. 2 months.
#         * Phase 4 (Refinement): Ongoing monitoring, optimization, and feature enhancements.  Ongoing.
#
#
# **X. Implementation Plan (Slide 10)**
#
# * **Title:** Project Timeline
# * **Gantt Chart:** Visual representation of the project timeline.
#     * **X-axis:** Time (months).
#     * **Y-axis:** Phases and tasks within each phase (e.g., development, testing, deployment, training).
#     * **Bars:** Represent the duration of each task.  Clearly indicate dependencies between tasks.
#
#
# **XI. Team and Resources (Slide 11)**
#
# * **Title:** Team and Resource Allocation
# * **Table:** Two columns: "Role" and "Resources."
#     * **Rows:**
#         * Software Engineers: 2 full-time
#         * Data Scientists: 1 full-time
#         * Cloud Architects: 1 part-time
#         * Legal Experts:  As needed (consulting)
#
#
# **XII. Cost and ROI (Slide 12)**
#
# * **Title:** Cost and Return on Investment
# * **Table:** Two columns: "Cost Category" and "Estimated Cost."
#     * **Rows:**
#         * Cloud Services: $X per month (detailed breakdown in appendix)
#         * Software Licenses: $Y (one-time cost)
#         * Personnel Costs: $Z per month
#         * Total: $T
# * **ROI Calculation:** Show the projected ROI based on quantified benefits (e.g., time savings, reduced risk).  "By reducing contract review time by X%, we project annual savings of $S, resulting in an ROI of R% within Y years."
#
#
# **XIII. Data Privacy and Security (Slide 13)**
#
# * **Title:** Data Privacy and Security
# * **Bullet Points:**
#     * Access Control:  Strict access controls based on roles and permissions.
#     * Encryption:  Data encryption at rest and in transit.
#     * Compliance:  Adherence to relevant data privacy regulations (e.g., GDPR, CCPA).
#     * Regular Audits:  Conduct regular security audits and penetration testing.
#
#
# **XIV. Future Enhancements (Slide 14)**
#
# * **Title:** Future Enhancements and Integrations
# * **Bullet Points:**
#     * Integration with CRM and legal management software.
#     * Expansion to other document types (e.g., invoices, proposals).
#     * Advanced analytics and reporting capabilities.
#     * Automated contract generation and review.
#
#
# **XV. Conclusion and Call to Action (Slide 15)**
#
# * **Title:**  Transform Your Contract Management Today
# * **Text:** "This AI-powered contract search system offers a significant opportunity to improve efficiency, reduce risk, and unlock the full potential of your contract data.  By approving this project, you are investing in a solution that will deliver substantial long-term benefits."
# * **Call to Action:** "We recommend proceeding with Phase 1 (Pilot) immediately.  We are confident that this solution will exceed your expectations."
#
#
# **Appendix (Optional)**
#
# * Detailed cost breakdown for cloud services.
# * Glossary of technical terms.
#
#
# This detailed plan ensures a clear and compelling presentation, addressing the client's needs and justifying the investment in the proposed solution.  The use of visuals, quantifiable data, and a clear implementation plan strengthens the proposal and increases the likelihood of approval.
