# %% [markdown]
# ## Planner prototyping
# Notebook for prototyping the powerpoint planner

# %%
import sys
sys.path.append("../") # go to parent dir
from llm.llmwrapper import LLM
from loguru import logger

# %%
llm = LLM(provider="gemini", model="gemini-1.5-pro")
# Out:
# INFO:root:LLM initialized
# INFO:root:Provider: gemini
# INFO:root:Model: gemini-1.5-pro

# %% [markdown]
# ### Step 1: brainstorm

# %%
query = "Make a presentation about building a system which takes an internal company database of contract documents, and based on a user query, helps find the most relevant contract document"

# %%
brainstorm_prompt = \
f"""
You are a tech consultant, and you have been given the following request:

"{query}"

Before starting work on the request, you need to brainstorm.
From a technical perspective, how could something like this be done? 
Please use the following pointers to guide your thought process:
- What is the most cutting-edge way to do this?
- How can this be done using cloud services?
"""
print(brainstorm_prompt)
# Out:
# You are a tech consultant, and you have been given the following request:
#
# "Make a presentation about building a system which takes an internal company database of contract documents, and based on a user query, helps find the most relevant contract document"
#
# Before starting work on the request, you need to brainstorm.
# From a technical perspective, how could something like this be done?
# Please use the following pointers to guide your thought process:
# - What is the most cutting-edge way to do this?
# - How can this be done using cloud services?

# %%
brainstorm_response = llm.call(query=brainstorm_prompt)
print(brainstorm_response['text'])
# Out:
# INFO:google_genai.models:AFC is enabled with max remote calls: 10.
# INFO:httpx:HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-1.5-pro:generateContent "HTTP/1.1 200 OK"
# INFO:google_genai.models:AFC remote call 1 is done.
# ## Brainstorming: Contract Document Search System
#
# **Goal:** Build a system that takes an internal company database of contract documents and, based on a user query, helps find the most relevant contract document.
#
# **Cutting-Edge Approach:**
#
# Leveraging a combination of **vector databases** and **large language models (LLMs)** offers the most cutting-edge solution. This approach allows for semantic search, going beyond keyword matching to understand the meaning and context of both the query and the contract documents.
#
# **Technical Breakdown:**
#
# 1. **Document Preprocessing:**
#     * **Optical Character Recognition (OCR):** If contracts are scanned images, OCR is crucial for extracting text.
#     * **Cleaning and Normalization:** Remove noise, standardize formatting, and handle special characters.
#     * **Chunking:** Divide contracts into smaller, manageable chunks (paragraphs or sections) for efficient processing.
#
# 2. **Embedding Generation:**
#     * **LLM-based Embeddings:** Utilize a powerful LLM (e.g., OpenAI's embeddings API, Sentence Transformers) to generate vector representations (embeddings) of each chunk. These embeddings capture the semantic meaning of the text.
#
# 3. **Vector Database:**
#     * **Store Embeddings:** Use a vector database (e.g., Pinecone, Weaviate, FAISS) to store the generated embeddings. These databases are optimized for similarity search.
#
# 4. **Query Processing:**
#     * **Embed the Query:**  When a user submits a query, generate its embedding using the same LLM used for document embeddings.
#     * **Similarity Search:** Perform a similarity search in the vector database using the query embedding. This retrieves the most semantically similar document chunks.
#     * **Ranking and Retrieval:** Rank the retrieved chunks based on similarity scores and potentially other factors like contract date, type, etc.  Return the most relevant contract documents containing these chunks.
#
# 5. **User Interface:**
#     * **Intuitive Search Interface:** Develop a user-friendly interface for submitting queries and displaying results.
#     * **Contextual Snippets:** Show relevant snippets from the retrieved contracts alongside the document title and other metadata.
#     * **Filtering and Faceting:** Allow users to filter results based on metadata like contract date, type, parties involved, etc.
#
# **Cloud Services Integration:**
#
# This system can be effectively built using cloud services:
#
# * **Document Storage:** AWS S3, Azure Blob Storage, or Google Cloud Storage for storing original contract documents.
# * **Compute:** AWS Lambda, Azure Functions, or Google Cloud Functions for serverless processing of documents and queries.
# * **Vector Database:** Managed vector database services like Pinecone or Weaviate, or self-hosted solutions on cloud VMs.
# * **LLM API:** Integrate with OpenAI's embeddings API or other cloud-based LLM services.
# * **Search Interface:** Build a web application using cloud-based frameworks and deploy it on platforms like AWS Elastic Beanstalk, Azure App Service, or Google App Engine.
#
#
# **Additional Considerations:**
#
# * **Security:** Implement appropriate security measures to protect sensitive contract data.
# * **Scalability:** Design the system to handle a growing number of contracts and user queries.
# * **Maintainability:** Use modular design and version control for easy maintenance and updates.
# * **Cost Optimization:** Choose cost-effective cloud services and optimize resource utilization.
# * **Legal and Compliance:** Ensure the system complies with relevant legal and regulatory requirements.
#
#
# This approach provides a robust and scalable solution for searching contract documents based on semantic understanding, leveraging the power of cutting-edge technologies and cloud services.

# %% [markdown]
# ### Step 2: Plan structure of presentation

# %%
skeleton_prompt = \
f"""
You are a tech consultant, and you have been given the following request:

"{query}"

After consulting with a senior software engineer, he has provided you the following approach to build such a system:
"{brainstorm_response['text']}"

It is now time for you to create the proposal slides.
Before deciding on what content should go on the slides, 
create a well-thought out plan of the structure that this presentation should follow.

Some of the sections you should include are:
- Title slide
- Executive summary slide
- The background of the problem
- Your proposed solution and why it will work / benefits of the solution
- The infrastructure and tech stack
- The required human resources
- The timeline
- The cost involved in this project

Depending on the situation, be creative and add in any other sections that you think might add value.
If this proposal is successful, you will get a big raise!
"""
print(skeleton_prompt)
# Out:
# You are a tech consultant, and you have been given the following request:
#
# "Make a presentation about building a system which takes an internal company database of contract documents, and based on a user query, helps find the most relevant contract document"
#
# After consulting with a senior software engineer, he has provided you the following approach to build such a system:
# "## Brainstorming: Contract Document Search System
#
# **Goal:** Build a system that takes an internal company database of contract documents and, based on a user query, helps find the most relevant contract document.
#
# **Cutting-Edge Approach:**
#
# Leveraging a combination of **vector databases** and **large language models (LLMs)** offers the most cutting-edge solution. This approach allows for semantic search, going beyond keyword matching to understand the meaning and context of both the query and the contract documents.
#
# **Technical Breakdown:**
#
# 1. **Document Preprocessing:**
#     * **Optical Character Recognition (OCR):** If contracts are scanned images, OCR is crucial for extracting text.
#     * **Cleaning and Normalization:** Remove noise, standardize formatting, and handle special characters.
#     * **Chunking:** Divide contracts into smaller, manageable chunks (paragraphs or sections) for efficient processing.
#
# 2. **Embedding Generation:**
#     * **LLM-based Embeddings:** Utilize a powerful LLM (e.g., OpenAI's embeddings API, Sentence Transformers) to generate vector representations (embeddings) of each chunk. These embeddings capture the semantic meaning of the text.
#
# 3. **Vector Database:**
#     * **Store Embeddings:** Use a vector database (e.g., Pinecone, Weaviate, FAISS) to store the generated embeddings. These databases are optimized for similarity search.
#
# 4. **Query Processing:**
#     * **Embed the Query:**  When a user submits a query, generate its embedding using the same LLM used for document embeddings.
#     * **Similarity Search:** Perform a similarity search in the vector database using the query embedding. This retrieves the most semantically similar document chunks.
#     * **Ranking and Retrieval:** Rank the retrieved chunks based on similarity scores and potentially other factors like contract date, type, etc.  Return the most relevant contract documents containing these chunks.
#
# 5. **User Interface:**
#     * **Intuitive Search Interface:** Develop a user-friendly interface for submitting queries and displaying results.
#     * **Contextual Snippets:** Show relevant snippets from the retrieved contracts alongside the document title and other metadata.
#     * **Filtering and Faceting:** Allow users to filter results based on metadata like contract date, type, parties involved, etc.
#
# **Cloud Services Integration:**
#
# This system can be effectively built using cloud services:
#
# * **Document Storage:** AWS S3, Azure Blob Storage, or Google Cloud Storage for storing original contract documents.
# * **Compute:** AWS Lambda, Azure Functions, or Google Cloud Functions for serverless processing of documents and queries.
# * **Vector Database:** Managed vector database services like Pinecone or Weaviate, or self-hosted solutions on cloud VMs.
# * **LLM API:** Integrate with OpenAI's embeddings API or other cloud-based LLM services.
# * **Search Interface:** Build a web application using cloud-based frameworks and deploy it on platforms like AWS Elastic Beanstalk, Azure App Service, or Google App Engine.
#
#
# **Additional Considerations:**
#
# * **Security:** Implement appropriate security measures to protect sensitive contract data.
# * **Scalability:** Design the system to handle a growing number of contracts and user queries.
# * **Maintainability:** Use modular design and version control for easy maintenance and updates.
# * **Cost Optimization:** Choose cost-effective cloud services and optimize resource utilization.
# * **Legal and Compliance:** Ensure the system complies with relevant legal and regulatory requirements.
#
#
# This approach provides a robust and scalable solution for searching contract documents based on semantic understanding, leveraging the power of cutting-edge technologies and cloud services.
# "
#
# It is now time for you to create the proposal slides.
# Before deciding on what content should go on the slides,
# create a well-thought out plan of the structure that this presentation should follow.
#
# Some of the sections you should include are:
# - Title slide
# - Executive summary slide
# - The background of the problem
# - Your proposed solution and why it will work / benefits of the solution
# - The infrastructure and tech stack
# - The required human resources
# - The timeline
# - The cost involved in this project
#
# Depending on the situation, be creative and add in any other sections that you think might add value.
# If this proposal is successful, you will get a big raise!

# %%
skeleton_response = llm.call(query=skeleton_prompt)
print(skeleton_response['text'])
# Out:
# INFO:google_genai.models:AFC is enabled with max remote calls: 10.
# INFO:httpx:HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-1.5-pro:generateContent "HTTP/1.1 200 OK"
# INFO:google_genai.models:AFC remote call 1 is done.
# ## Presentation Structure Plan: Contract Document Search System
#
# This plan outlines the structure of a presentation proposing a cutting-edge contract document search system. The goal is to secure approval and funding for the project, highlighting the benefits and feasibility of the proposed solution.
#
# **I. Title Slide (1 slide)**
#
# * **Title:**  Revolutionizing Contract Search: A Semantic Approach
# * **Subtitle:**  Unlocking the Power of Your Contract Data
# * **Your Name/Title**
# * **Company Name/Logo**
# * **Date**
#
# **II. Executive Summary (1 slide)**
#
# * **Problem:** Briefly state the current challenges with contract document search (inefficient, keyword-based, time-consuming).
# * **Solution:** Introduce the proposed semantic search system leveraging LLMs and vector databases.
# * **Key Benefits:** Highlight 2-3 core benefits (e.g., improved accuracy, faster search, better insights).
# * **Expected ROI:** Briefly mention potential return on investment (e.g., time saved, reduced legal risks).
#
# **III. The Challenge: Current State of Contract Search (2 slides)**
#
# * **Slide 1: Pain Points:** Describe the current inefficiencies and limitations of keyword-based search.  Use visuals (e.g., flowchart depicting a cumbersome manual search process).  Include quantifiable metrics if available (e.g., average time spent searching for contracts, estimated cost of inefficiencies).
# * **Slide 2: Lost Opportunities:**  Explain how improved contract search can unlock valuable insights and support better decision-making.  Examples: identifying contract renewal dates, analyzing contract terms across different vendors, proactively managing risks.
#
# **IV. The Solution: Semantic Search with LLMs and Vector Databases (3 slides)**
#
# * **Slide 1: Overview:** Introduce the concept of semantic search and how it differs from keyword search. Explain how LLMs understand the meaning and context of text.
# * **Slide 2: Technical Architecture:**  Present a simplified diagram illustrating the system architecture (document preprocessing, embedding generation, vector database, query processing).
# * **Slide 3: Benefits of the Proposed Solution:**  Elaborate on the key advantages: improved accuracy, faster search, enhanced user experience, scalability, and better insights.  Quantify benefits whenever possible (e.g., "Expected to reduce search time by X%").
#
# **V. Technology Stack and Infrastructure (2 slides)**
#
# * **Slide 1: Core Technologies:**  List the chosen technologies (e.g., OpenAI embeddings API, Pinecone, AWS S3, etc.) and justify their selection based on performance, scalability, cost-effectiveness, and security.
# * **Slide 2: Infrastructure Diagram:**  Visualize the cloud infrastructure, highlighting key components and their interactions.  Emphasize scalability and security aspects.
#
# **VI. Human Resources and Expertise (1 slide)**
#
# * **Team Composition:** Outline the required roles and expertise (e.g., software engineers, data scientists, cloud architects, legal experts).
# * **Resourcing Strategy:** Explain how the team will be assembled (internal resources, external consultants, or a combination).
#
# **VII. Project Timeline and Milestones (1 slide)**
#
# * **Phased Approach:** Present a clear timeline with key milestones (e.g., data preprocessing, system development, testing, deployment, training).
# * **Gantt Chart:**  Use a Gantt chart to visualize the project schedule and dependencies.
#
# **VIII. Cost Estimation and ROI (2 slides)**
#
# * **Slide 1: Cost Breakdown:**  Provide a detailed breakdown of project costs (e.g., cloud services, software licenses, personnel costs, consulting fees).
# * **Slide 2: Return on Investment:**  Quantify the expected ROI by comparing the cost of the system with the potential benefits (e.g., time savings, reduced legal risks, improved decision-making).
#
# **IX.  Security and Compliance (1 slide)**
#
# * **Data Security:**  Address data security measures, including access control, encryption, and compliance with relevant regulations (e.g., GDPR, CCPA).
# * **Legal and Ethical Considerations:**  Highlight any legal or ethical implications related to the use of AI and contract data.
#
# **X.  Future Enhancements and Scalability (1 slide)**
#
# * **Future Roadmap:** Briefly discuss potential future enhancements (e.g., integration with other systems, advanced analytics, AI-powered contract drafting).
# * **Scalability:**  Reiterate the system's scalability to handle future growth in contract volume and user queries.
#
# **XI.  Call to Action and Q&A (1 slide)**
#
# * **Recommendation:**  Clearly state the recommended course of action (approve the project and allocate funding).
# * **Q&A:**  Open the floor for questions and discussion.
#
#
# This structured approach will ensure a clear, concise, and persuasive presentation that effectively communicates the value and feasibility of the proposed contract document search system.  The use of visuals, quantifiable metrics, and a focus on benefits will strengthen the proposal and increase the likelihood of securing approval and funding.

# %% [markdown]
# ### Step 3: Create slide content

# %%
slide_content_prompt = \
f"""
You are a tech consultant, and you have been given the following request:

"{query}"

After consulting with a senior software engineer, he has provided you the following approach to build such a system:
"{brainstorm_response['text']}"

Based on the advice of the senior software engineer, you have planned out your presentation:
"{skeleton_response['text']}"

Following the plan you have created above, and referencing the technical advice of the senior software engineer,
describe the content that will appear on EACH slide in detail.

Pay extra attention to the following points:
1) If a diagram or image should go on a slide (e.g. an infrastructure diagram, organization chart or a GANTT chart etc.), 
you must describe it with enough detail such that someone reading the description would be able to reproduce it perfectly.

2) This slide content plan will be passed on to another person, so the slide descriptions must be as precise and specific as possible.

3) Think carefully about whether or not the needs of the client are being met with this proposal.

4) Make sure to include the content that should appear on the title slide.

If this proposal is successful, you will get a big raise!

IMPORTANT: Make sure to separate the content of each slide with the following markers <Slide X START> and <Slide X END>, where X represents the slide number.
"""
print(slide_content_prompt)
# Out:
# You are a tech consultant, and you have been given the following request:
#
# "Make a presentation about building a system which takes an internal company database of contract documents, and based on a user query, helps find the most relevant contract document"
#
# After consulting with a senior software engineer, he has provided you the following approach to build such a system:
# "## Brainstorming: Contract Document Search System
#
# **Goal:** Build a system that takes an internal company database of contract documents and, based on a user query, helps find the most relevant contract document.
#
# **Cutting-Edge Approach:**
#
# Leveraging a combination of **vector databases** and **large language models (LLMs)** offers the most cutting-edge solution. This approach allows for semantic search, going beyond keyword matching to understand the meaning and context of both the query and the contract documents.
#
# **Technical Breakdown:**
#
# 1. **Document Preprocessing:**
#     * **Optical Character Recognition (OCR):** If contracts are scanned images, OCR is crucial for extracting text.
#     * **Cleaning and Normalization:** Remove noise, standardize formatting, and handle special characters.
#     * **Chunking:** Divide contracts into smaller, manageable chunks (paragraphs or sections) for efficient processing.
#
# 2. **Embedding Generation:**
#     * **LLM-based Embeddings:** Utilize a powerful LLM (e.g., OpenAI's embeddings API, Sentence Transformers) to generate vector representations (embeddings) of each chunk. These embeddings capture the semantic meaning of the text.
#
# 3. **Vector Database:**
#     * **Store Embeddings:** Use a vector database (e.g., Pinecone, Weaviate, FAISS) to store the generated embeddings. These databases are optimized for similarity search.
#
# 4. **Query Processing:**
#     * **Embed the Query:**  When a user submits a query, generate its embedding using the same LLM used for document embeddings.
#     * **Similarity Search:** Perform a similarity search in the vector database using the query embedding. This retrieves the most semantically similar document chunks.
#     * **Ranking and Retrieval:** Rank the retrieved chunks based on similarity scores and potentially other factors like contract date, type, etc.  Return the most relevant contract documents containing these chunks.
#
# 5. **User Interface:**
#     * **Intuitive Search Interface:** Develop a user-friendly interface for submitting queries and displaying results.
#     * **Contextual Snippets:** Show relevant snippets from the retrieved contracts alongside the document title and other metadata.
#     * **Filtering and Faceting:** Allow users to filter results based on metadata like contract date, type, parties involved, etc.
#
# **Cloud Services Integration:**
#
# This system can be effectively built using cloud services:
#
# * **Document Storage:** AWS S3, Azure Blob Storage, or Google Cloud Storage for storing original contract documents.
# * **Compute:** AWS Lambda, Azure Functions, or Google Cloud Functions for serverless processing of documents and queries.
# * **Vector Database:** Managed vector database services like Pinecone or Weaviate, or self-hosted solutions on cloud VMs.
# * **LLM API:** Integrate with OpenAI's embeddings API or other cloud-based LLM services.
# * **Search Interface:** Build a web application using cloud-based frameworks and deploy it on platforms like AWS Elastic Beanstalk, Azure App Service, or Google App Engine.
#
#
# **Additional Considerations:**
#
# * **Security:** Implement appropriate security measures to protect sensitive contract data.
# * **Scalability:** Design the system to handle a growing number of contracts and user queries.
# * **Maintainability:** Use modular design and version control for easy maintenance and updates.
# * **Cost Optimization:** Choose cost-effective cloud services and optimize resource utilization.
# * **Legal and Compliance:** Ensure the system complies with relevant legal and regulatory requirements.
#
#
# This approach provides a robust and scalable solution for searching contract documents based on semantic understanding, leveraging the power of cutting-edge technologies and cloud services.
# "
#
# Based on the advice of the senior software engineer, you have planned out your presentation:
# "## Presentation Structure Plan: Contract Document Search System
#
# This plan outlines the structure of a presentation proposing a cutting-edge contract document search system. The goal is to secure approval and funding for the project, highlighting the benefits and feasibility of the proposed solution.
#
# **I. Title Slide (1 slide)**
#
# * **Title:**  Revolutionizing Contract Search: A Semantic Approach
# * **Subtitle:**  Unlocking the Power of Your Contract Data
# * **Your Name/Title**
# * **Company Name/Logo**
# * **Date**
#
# **II. Executive Summary (1 slide)**
#
# * **Problem:** Briefly state the current challenges with contract document search (inefficient, keyword-based, time-consuming).
# * **Solution:** Introduce the proposed semantic search system leveraging LLMs and vector databases.
# * **Key Benefits:** Highlight 2-3 core benefits (e.g., improved accuracy, faster search, better insights).
# * **Expected ROI:** Briefly mention potential return on investment (e.g., time saved, reduced legal risks).
#
# **III. The Challenge: Current State of Contract Search (2 slides)**
#
# * **Slide 1: Pain Points:** Describe the current inefficiencies and limitations of keyword-based search.  Use visuals (e.g., flowchart depicting a cumbersome manual search process).  Include quantifiable metrics if available (e.g., average time spent searching for contracts, estimated cost of inefficiencies).
# * **Slide 2: Lost Opportunities:**  Explain how improved contract search can unlock valuable insights and support better decision-making.  Examples: identifying contract renewal dates, analyzing contract terms across different vendors, proactively managing risks.
#
# **IV. The Solution: Semantic Search with LLMs and Vector Databases (3 slides)**
#
# * **Slide 1: Overview:** Introduce the concept of semantic search and how it differs from keyword search. Explain how LLMs understand the meaning and context of text.
# * **Slide 2: Technical Architecture:**  Present a simplified diagram illustrating the system architecture (document preprocessing, embedding generation, vector database, query processing).
# * **Slide 3: Benefits of the Proposed Solution:**  Elaborate on the key advantages: improved accuracy, faster search, enhanced user experience, scalability, and better insights.  Quantify benefits whenever possible (e.g., "Expected to reduce search time by X%").
#
# **V. Technology Stack and Infrastructure (2 slides)**
#
# * **Slide 1: Core Technologies:**  List the chosen technologies (e.g., OpenAI embeddings API, Pinecone, AWS S3, etc.) and justify their selection based on performance, scalability, cost-effectiveness, and security.
# * **Slide 2: Infrastructure Diagram:**  Visualize the cloud infrastructure, highlighting key components and their interactions.  Emphasize scalability and security aspects.
#
# **VI. Human Resources and Expertise (1 slide)**
#
# * **Team Composition:** Outline the required roles and expertise (e.g., software engineers, data scientists, cloud architects, legal experts).
# * **Resourcing Strategy:** Explain how the team will be assembled (internal resources, external consultants, or a combination).
#
# **VII. Project Timeline and Milestones (1 slide)**
#
# * **Phased Approach:** Present a clear timeline with key milestones (e.g., data preprocessing, system development, testing, deployment, training).
# * **Gantt Chart:**  Use a Gantt chart to visualize the project schedule and dependencies.
#
# **VIII. Cost Estimation and ROI (2 slides)**
#
# * **Slide 1: Cost Breakdown:**  Provide a detailed breakdown of project costs (e.g., cloud services, software licenses, personnel costs, consulting fees).
# * **Slide 2: Return on Investment:**  Quantify the expected ROI by comparing the cost of the system with the potential benefits (e.g., time savings, reduced legal risks, improved decision-making).
#
# **IX.  Security and Compliance (1 slide)**
#
# * **Data Security:**  Address data security measures, including access control, encryption, and compliance with relevant regulations (e.g., GDPR, CCPA).
# * **Legal and Ethical Considerations:**  Highlight any legal or ethical implications related to the use of AI and contract data.
#
# **X.  Future Enhancements and Scalability (1 slide)**
#
# * **Future Roadmap:** Briefly discuss potential future enhancements (e.g., integration with other systems, advanced analytics, AI-powered contract drafting).
# * **Scalability:**  Reiterate the system's scalability to handle future growth in contract volume and user queries.
#
# **XI.  Call to Action and Q&A (1 slide)**
#
# * **Recommendation:**  Clearly state the recommended course of action (approve the project and allocate funding).
# * **Q&A:**  Open the floor for questions and discussion.
#
#
# This structured approach will ensure a clear, concise, and persuasive presentation that effectively communicates the value and feasibility of the proposed contract document search system.  The use of visuals, quantifiable metrics, and a focus on benefits will strengthen the proposal and increase the likelihood of securing approval and funding.
# "
#
# Following the plan you have created above, and referencing the technical advice of the senior software engineer,
# describe the content that will appear on EACH slide in detail.
#
# Pay extra attention to the following points:
# 1) If a diagram or image should go on a slide (e.g. an infrastructure diagram, organization chart or a GANTT chart etc.),
# you must describe it with enough detail such that someone reading the description would be able to reproduce it perfectly.
#
# 2) This slide content plan will be passed on to another person, so the slide descriptions must be as precise and specific as possible.
#
# 3) Think carefully about whether or not the needs of the client are being met with this proposal.
#
# 4) Make sure to include the content that should appear on the title slide.
#
# If this proposal is successful, you will get a big raise!
#
# IMPORTANT: Make sure to separate the content of each slide with the following markers <Slide X START> and <Slide X END>, where X represents the slide number.

# %%
slide_content_response = llm.call(query=slide_content_prompt)['text']
print(slide_content_response)
# Out:
# INFO:google_genai.models:AFC is enabled with max remote calls: 10.
# INFO:httpx:HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-1.5-pro:generateContent "HTTP/1.1 200 OK"
# INFO:google_genai.models:AFC remote call 1 is done.
# <Slide 1 START>
#
# * **Title:** Revolutionizing Contract Search: A Semantic Approach
# * **Subtitle:** Unlocking the Power of Your Contract Data
# * **Your Name/Title:** [Your Name], Tech Consultant
# * **Company Name/Logo:** [Your Company Name and Logo]
# * **Date:** [Date of Presentation]
#
# <Slide 1 END>
#
#
# <Slide 2 START>
#
# * **Title:** Executive Summary
# * **Problem:**  Currently, locating specific information within our contract database is a slow, manual, and frustrating process. Keyword searches often yield irrelevant results, requiring extensive time and effort to sift through numerous documents. This inefficiency hinders productivity and can lead to missed deadlines and potential legal risks.
# * **Solution:** We propose a cutting-edge semantic search system that leverages the power of Large Language Models (LLMs) and vector databases. This intelligent system understands the meaning and context of your queries, delivering highly accurate and relevant results quickly.
# * **Key Benefits:** Increased efficiency (reduced search time), improved accuracy (find the right contract every time), and enhanced risk management (proactive identification of critical clauses and deadlines).
# * **Expected ROI:**  By streamlining contract search, we project a significant reduction in time spent on manual searches, estimated at [quantify time savings, e.g., 50%], translating to [quantify cost savings, e.g., $X annually] and minimizing potential legal risks.
#
# <Slide 2 END>
#
#
# <Slide 3 START>
#
# * **Title:** The Challenge: Current State of Contract Search - Pain Points
# * **Content:** A flowchart depicting the current manual contract search process:
#     1. User enters keywords into the search bar.
#     2. System returns a large number of irrelevant results.
#     3. User manually reviews each document, often opening and scanning multiple files.
#     4. Process is time-consuming and frustrating, leading to low user satisfaction.
# * **Metrics:** Average time spent searching for a contract: [quantify, e.g., 30 minutes]. Estimated cost of inefficiencies due to manual search: [quantify, e.g., $Y annually].
#
# <Slide 3 END>
#
#
# <Slide 4 START>
#
# * **Title:** The Challenge: Current State of Contract Search - Lost Opportunities
# * **Content:**  Bulleted list of lost opportunities due to inefficient contract search:
#     * Difficulty in identifying key contract renewal dates, leading to missed opportunities for renegotiation.
#     * Inability to effectively analyze contract terms across different vendors, hindering cost optimization efforts.
#     * Limited capacity for proactive risk management due to challenges in identifying critical clauses and obligations.
#     * Slow response times to legal inquiries and audits, increasing potential legal exposure.
#
# <Slide 4 END>
#
#
# <Slide 5 START>
#
# * **Title:** The Solution: Semantic Search - Understanding Meaning
# * **Content:**  Explanation of semantic search:  "Unlike keyword search, which relies on matching exact words, semantic search understands the *meaning* behind your query.  It considers the context and relationships between words to deliver more relevant results."  Visual:  Two side-by-side examples.  One showing a keyword search for "liability" returning irrelevant results about employee liability when the user is searching for product liability. The other showing a semantic search for "product liability" returning accurate results.  Brief explanation of how LLMs understand meaning and context through training on massive datasets of text.
#
# <Slide 5 END>
#
#
# <Slide 6 START>
#
# * **Title:** The Solution: Technical Architecture
# * **Content:** A diagram illustrating the system architecture:
#     1. **Document Preprocessing (OCR, Cleaning, Chunking):** A box labeled "Contract Documents" points to a box labeled "Preprocessing" which then points to "Document Chunks".
#     2. **Embedding Generation (LLM):** A box labeled "LLM" receives input from "Document Chunks" and outputs "Embeddings".
#     3. **Vector Database:** A box labeled "Vector Database" stores the "Embeddings".
#     4. **Query Processing (Embed Query, Similarity Search, Ranking):** A box labeled "User Query" points to a box labeled "LLM" which outputs "Query Embedding". This "Query Embedding" interacts with the "Vector Database" which outputs "Relevant Chunks".  These "Relevant Chunks" are then processed by a box labeled "Ranking" which outputs "Ranked Results".
#     5. **User Interface:** A box labeled "User Interface" displays the "Ranked Results".
#
# <Slide 6 END>
#
#
# <Slide 7 START>
#
# * **Title:** The Solution: Key Benefits
# * **Content:** Bulleted list of benefits:
#     * **Improved Accuracy:**  Find the precise contract clauses and information you need, even if the wording doesn't exactly match your query. (Expected to increase search precision by X%)
#     * **Faster Search:**  Reduce search time significantly, freeing up valuable time for other tasks. (Expected to reduce search time by Y%)
#     * **Enhanced User Experience:**  Intuitive interface with contextual snippets and filtering options for easy navigation and analysis.
#     * **Scalability:**  Handles a growing number of contracts and user queries without performance degradation.
#     * **Better Insights:**  Unlock valuable insights from your contract data to support better decision-making.
#
# <Slide 7 END>
#
#
# <Slide 8 START>
#
# * **Title:** Technology Stack and Infrastructure - Core Technologies
# * **Content:**  Table listing chosen technologies and justifications:
#     * **LLM Embeddings:** OpenAI embeddings API -  Industry-leading performance and accuracy in generating semantic embeddings.
#     * **Vector Database:** Pinecone -  Managed service offering scalability, performance, and ease of use.
#     * **Document Storage:** AWS S3 - Secure, scalable, and cost-effective storage for contract documents.
#     * **Compute:** AWS Lambda - Serverless compute for efficient processing of documents and queries.
#     * **Search Interface:** React - Modern JavaScript framework for building a responsive and user-friendly interface.
#
# <Slide 8 END>
#
#
# <Slide 9 START>
#
# * **Title:** Technology Stack and Infrastructure - Infrastructure Diagram
# * **Content:** A diagram visualizing the cloud infrastructure:
#     * **User Interface:** A box labeled "User Interface" (React application) interacts with "API Gateway".
#     * **API Gateway:** A box labeled "API Gateway" connects to "Lambda Functions".
#     * **Lambda Functions:** A box labeled "Lambda Functions" interacts with both "Pinecone (Vector Database)" and "S3 (Document Storage)".
#     * **Pinecone (Vector Database):** A box labeled "Pinecone" stores embeddings.
#     * **S3 (Document Storage):** A box labeled "S3" stores contract documents.
#     * **OpenAI API:** A box labeled "OpenAI API" provides embeddings.  Arrows indicate the flow of data between components.
#
# <Slide 9 END>
#
#
# <Slide 10 START>
#
# * **Title:** Human Resources and Expertise
# * **Content:**
#     * **Team Composition:**  Software Engineers (2), Data Scientist (1), Cloud Architect (1), Legal Expert (1, part-time).
#     * **Resourcing Strategy:**  Leverage existing internal software engineering and cloud architecture resources. Supplement with external data science and legal expertise as needed.
#
# <Slide 10 END>
#
#
# <Slide 11 START>
#
# * **Title:** Project Timeline and Milestones
# * **Content:** A Gantt chart visualizing the project timeline:
#     * **Phase 1: Data Preprocessing (2 months):** OCR, cleaning, and chunking of existing contract documents.
#     * **Phase 2: System Development (4 months):**  Building the core search functionality, integrating with APIs, and developing the user interface.
#     * **Phase 3: Testing and Refinement (1 month):**  Rigorous testing and refinement based on user feedback.
#     * **Phase 4: Deployment and Training (1 month):**  Deploying the system to production and providing user training.
#
# <Slide 11 END>
#
#
# <Slide 12 START>
#
# * **Title:** Cost Estimation
# * **Content:** A table detailing project costs:
#     * Cloud Services (AWS S3, Lambda, Pinecone): $[Cost]
#     * Software Licenses (OpenAI API): $[Cost]
#     * Personnel Costs (Internal & External): $[Cost]
#     * Total Estimated Cost: $[Total Cost]
#
# <Slide 12 END>
#
#
# <Slide 13 START>
#
# * **Title:** Return on Investment
# * **Content:**  Comparison of system cost with potential benefits:
#     * **Cost of System:** $[Total Cost from previous slide]
#     * **Benefits:**
#         * Time Savings from Reduced Search Time: $[Quantified Savings]
#         * Reduced Legal Risks (estimated): $[Quantified Savings]
#         * Improved Decision-Making (qualitative benefit)
#     * **Estimated ROI:** [Calculate ROI based on quantified benefits]
#
# <Slide 13 END>
#
#
# <Slide 14 START>
#
# * **Title:** Security and Compliance
# * **Content:**
#     * **Data Security:**  Access control restrictions, data encryption at rest and in transit, regular security audits. Compliance with relevant data privacy regulations (e.g., GDPR, CCPA).
#     * **Legal and Ethical Considerations:**  Ensuring the system's use aligns with ethical AI principles and legal requirements regarding data privacy and contract confidentiality.  Regular reviews by legal counsel.
#
# <Slide 14 END>
#
#
# <Slide 15 START>
#
# * **Title:** Future Enhancements and Scalability
# * **Content:**
#     * **Future Roadmap:**  Integration with other internal systems (e.g., CRM, contract management software). Advanced analytics and reporting capabilities. AI-powered contract drafting assistance.
#     * **Scalability:** The system is designed to handle future growth in contract volume and user queries through the use of scalable cloud services and a distributed architecture.
#
# <Slide 15 END>
#
#
# <Slide 16 START>
#
# * **Title:** Call to Action & Q&A
# * **Recommendation:** We strongly recommend approving this project and allocating the necessary funding to implement this cutting-edge contract search system.  This investment will significantly improve efficiency, reduce risks, and unlock valuable insights from your contract data.
# * **Q&A:** Open the floor for questions.
#
# <Slide 16 END>
